# ...

# %%
total = robbery.append(break_enter).append(theft_over)

# %%
total.loc[total['occurrencehour'] == 9]
# Out:
#               X          Y  Index_ event_unique_id            occurrencedate  \
# 117  -79.140915  43.789661    1369  GO-20141272785  2014-01-03T05:00:00.000Z
# 177  -79.362785  43.810722    1886  GO-20141820269  2014-04-02T04:00:00.000Z
# 217  -79.370125  43.656166    2273  GO-20141869029  2014-04-11T04:00:00.000Z
# 240  -79.371033  43.658295    2427  GO-20141341661  2014-01-14T05:00:00.000Z
# 277  -79.541122  43.750961    2697  GO-20141401446  2014-01-24T05:00:00.000Z
# 321  -79.382118  43.659100    4896  GO-20142043786  2014-05-09T04:00:00.000Z
# 323  -79.215836  43.761856    4945  GO-20142043737  2014-05-09T04:00:00.000Z
# 479  -79.415573  43.779770    6150  GO-20141303385  2014-01-08T05:00:00.000Z
# 583  -79.315636  43.750919    1043  GO-20141883572  2014-01-07T05:00:00.000Z
# 612  -79.578308  43.735508    3520  GO-20141602694  2014-02-26T05:00:00.000Z
# 665  -79.410248  43.662670    3842  GO-20141557266  2014-02-19T05:00:00.000Z
# ...

# %%
total.reset_index(inplace=True)

# %%
total.drop('index', axis=1, inplace=True)

# %%
total
# Out:
#                X          Y  Index_ event_unique_id            occurrencedate  \
# 0     -79.434601  43.731232    4078  GO-20141653708  2014-03-06T05:00:00.000Z
# 1     -79.603912  43.743645    4082  GO-20141654152  2014-03-06T05:00:00.000Z
# 2     -79.603912  43.743645    4083  GO-20141654152  2014-03-06T05:00:00.000Z
# 3     -79.548676  43.701328    4086  GO-20141650227  2014-03-06T05:00:00.000Z
# 4     -79.261131  43.773617    4088  GO-20141652543  2014-03-06T05:00:00.000Z
# 5     -79.312111  43.748836    4090  GO-20141653746  2014-03-06T05:00:00.000Z
# 6     -79.312111  43.748836    4091  GO-20141653746  2014-03-06T05:00:00.000Z
# 7     -79.603912  43.743645    4092  GO-20141654152  2014-03-06T05:00:00.000Z
# 8     -79.374847  43.660656    4095  GO-20141686658  2014-03-06T05:00:00.000Z
# 9     -79.445992  43.729061    4108  GO-20141654000  2014-03-06T05:00:00.000Z
# 10    -79.392090  43.648853    4114  GO-20141700443  2014-03-12T04:00:00.000Z
# ...

# %%
plt.scatter(total['X'], total['Y'])

# %%
latlng = '43.748836,-79.312111'
geocode = requests.get('https://maps.googleapis.com/maps/api/geocode/json?latlng=' + str(latlng) + '&key=AIzaSyCY70odCXKsZf7a-u7e1Hdyha3nIEwoICo')

# %%
results = geocode.json()

# %%
results
# Out:
# {'plus_code': {'compound_code': 'PMXQ+G5 Toronto, ON, Canada',
#   'global_code': '87M2PMXQ+G5'},
#  'results': [{'address_components': [{'long_name': '1941',
#      'short_name': '1941',
#      'types': ['street_number']},
#     {'long_name': 'Victoria Park Avenue',
#      'short_name': 'Victoria Park Ave',
#      'types': ['route']},
#     {'long_name': 'North York',
#      'short_name': 'North York',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Toronto',
#      'short_name': 'Toronto',
#      'types': ['locality', 'political']},
#     {'long_name': 'Toronto Division',
#      'short_name': 'Toronto Division',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Ontario',
#      'short_name': 'ON',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Canada',
#      'short_name': 'CA',
#      'types': ['country', 'political']},
#     {'long_name': 'M1R 1T9',
# ...
